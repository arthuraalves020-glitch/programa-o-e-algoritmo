# %%
#laços e interção

print ("olá mundo!")
print ("olá mundo!")
print ("olá mundo!")
print ("olá mundo!")
print ("olá mundo!")
print ("olá mundo!")

# %%
for i in range (7):
  print ("olá mundo!")
# Out:
# olá mundo!
# olá mundo!
# olá mundo!
# olá mundo!
# olá mundo!
# olá mundo!
# olá mundo!

# %%
for i in range (7):
  print (1 + i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
palavra = "python"
invertida = ""
for i in (palavra):
  invertida = i + invertida
  print (invertida)
# Out:
# p
# yp
# typ
# htyp
# ohtyp
# nohtyp

# %%
#escrever um programa que o usuario digita uma palavra e verifica se a palavra é palindromo e imprime a palavra

palavra = input("Digite uma palavra: ")

palavra_inv = palavra[::-1]

if palavra == palavra_inv:
    print(f"A palavra '{palavra}' é um palíndromo.")
else:
    print(f"A palavra '{palavra}' não é um palíndromo.")
# Out:
# Digite uma palavra: ana
# A palavra 'ana' é um palíndromo.

# %%
#escrever um programa que o usuario digita um numero e o programa imprime os numeros pares de zero ate o numero
